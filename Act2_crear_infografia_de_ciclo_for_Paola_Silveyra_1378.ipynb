# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051281378-beep/UIII-Act2-ejemplos-ciclos-for-Paola-Silveyra-1378/blob/main/Act2_crear_infografia_de_ciclo_for_Paola_Silveyra_1378.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Paola Silveyra NL = 50 Fecha 06/05/26
# #### Infografia de ciclo for

# %%
# Ejemplo 1: recorrer números del 1 al 5

for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Ejemplo 2: recorrer una lista

frutas = ["manzana", "pera", "uva", "kiwi"]

for fruta in frutas:
    print(fruta)
# Out:
# manzana
# pera
# uva
# kiwi

# %%
# Ejemplo 3: suma de números

suma = 0

for i in range(1, 6):
    suma = suma + i

print("La suma es:", suma)
# Out:
# La suma es: 15

# %%
# Ejemplo 4: recorrer una cadena

palabra = "Python"

for letra in palabra:
    print(letra)
# Out:
# P
# y
# t
# h
# o
# n

# %%
# Ejemplo 5: tabla de multiplicar del 3

tabla = 3

for i in range(1, 11):
    print(f"{tabla} x {i} = {tabla * i}")
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
# Ejemplo 6: números pares del 1 al 10

for numero in range(1, 11):

    if numero % 2 == 0:
        print(numero)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# Ejemplo 7: cuenta regresiva

for i in range(5, 0, -1):
    print(i)

print("Despegue")
# Out:
# 5
# 4
# 3
# 2
# 1
# Despegue

# %%
# Ejemplo 8: mensaje personalizado

nombre = "Paola"

for i in range(3):
    print("Hola", nombre)
# Out:
# Hola Paola
# Hola Paola
# Hola Paola

# %% [markdown]
# <img src="https://raw.githubusercontent.com/a25308051281378-beep/UIII-Act2-ejemplos-ciclos-for-Paola-Silveyra-1378/refs/heads/main/UIII%20Act2%20infografiaciclofor.png">
